# %%
from ultralytics import YOLO
yolo = YOLO(model="yolo11n.pt", task="detect")
result = yolo(
    source="./beij.webp", 
    save=True, 
    save_txt=True, 
    show_labels=True,
    show_boxes=True
)

print(result[0].boxes)
# Out:
# image 1/1 /Volumes/work/code/personal/ai-learn/yolo/learn/beij.webp: 480x640 2 persons, 2 bicycles, 8 cars, 1 traffic light, 45.8ms
# Speed: 1.1ms preprocess, 45.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict12
# 1 label saved to runs/detect/predict12/labels
# ultralytics.engine.results.Boxes object with attributes:
#
# cls: tensor([2., 1., 0., 2., 2., 0., 2., 2., 1., 2., 2., 9., 2.])
# conf: tensor([0.9059, 0.8499, 0.8102, 0.8029, 0.7562, 0.7229, 0.6635, 0.5710, 0.5396, 0.5263, 0.4922, 0.3278, 0.3079])
# data: tensor([[4.2629e+02, 1.9855e+02, 5.7584e+02, 3.0237e+02, 9.0594e-01, 2.0000e+00],
#         [9.7469e+01, 2.5438e+02, 2.6432e+02, 4.0945e+02, 8.4985e-01, 1.0000e+00],
#         [1.3339e+02, 1.8212e+02, 2.3441e+02, 3.6193e+02, 8.1020e-01, 0.0000e+00],
#         [2.3781e-01, 1.8931e+02, 2.7581e+02, 3.3461e+02, 8.0294e-01, 2.0000e+00],
#         [5.2353e+02, 1.9372e+02, 5.9798e+02, 2.6157e+02, 7.5623e-01, 2.0000e+00],
# ...

# %%
c = a + a
print(c)
# Out:
# 246
